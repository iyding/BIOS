# %%
# Sports Analytics: Ivy League
# Note: the data is from 2023; I scraped the Dartmouth Football 2023 roster into a dataframe just to try it out,
# maybe the code will be useful for other schools

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

import matplotlib.pyplot as plt
import pandas as pd
import time
import re

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver

from IPython.display import display, Image

# %%
b = webdriver.Chrome()
url = "https://dartmouthsports.com/sports/football/roster"
b.get(url)

# %%
#finding the column names to construct a data frame
#tbh I don't really use this cell later on, but kept just in case
tbl = b.find_elements("tag name", "tr")

column_names = []


for rows in tbl:
    cells = rows.find_elements("tag name", "td")
    for cell in cells:
        name = cell.get_attribute("class")
        
        if name not in column_names:
            # the line below is hardcoding??? point is I don't want these in the dataframe
            if name != "image_combined_path noprint" and name != "" and name != "image_combined_path hide-on-small-down noprint":
                column_names.append(name)
            else:
                continue

column_names
# Out:
# ['roster_jerseynum ',
#  'sidearm-table-player-name ',
#  'rp_position_short ',
#  'height ',
#  'rp_weight ',
#  'roster_class ',
#  'player_highschool ',
#  'player_hometown ']

# %%
#list containing information for each player

info = []

body = b.find_elements("tag name", "tbody")

#there are 3 tables on the webpage; only want the first one containing player information
t = body[0]

tbl = t.find_elements("tag name", "tr")

for rows in tbl:
    cells = rows.find_elements("tag name", "td")
    for cell in cells:
        info.append(cell.text)
info
# Out:
# ['0',
#  'Josiah Green',
#  'DL',
#  '6-0',
#  '265',
#  'Jr.',
#  'North Central',
#  'Indianapolis, Ind.',
#  '1',
#  'Davis Golick',
#  'P',
#  '6-1',
#  '210',
#  'Jr.',
#  'Woodward Academy',
#  'Smyrna, Ga.',
#  '2',
#  'Cam Maddox',
#  'S',
#  '6-2',
#  '205',
#  'Sr.',
#  'Sun Valley/Cheshire Academy (Conn.)',
#  'Monroe, N.C.',
#  '3',
#  'Isaac Boston',
#  'WR',
#  '5-10',
#  '180',
#  'Sr.',
#  'Springfield Central',
#  'Springfield, Mass.',
#  '4',
#  'Leonard St. Gourdin',
#  'S',
#  '6-3',
#  '205',
#  'Sr.',
#  'Malden Catholic/Deerfield Academy',
#  'Malden, Mass.',
#  '5',
#  'Tyson McCloud',
#  'NB',
#  '6-1',
#  '190',
#  'Sr.',
#  'North Broward Prep',
#  'Coconut Creek, Fla.',
#  '6',
#  'Joey Richmond',
#  'RB',
#  '5-11',
#  '230',
#  'Sr.',
#  'Glenbard West',
#  'Glen Ellyn, Ill.',
#  '6',
#  'Samuel Washington',
#  'DB',
#  '6-2',
#  '185',
#  'Fy.',
#  'Martin Luther King',
#  'Detroit, Mich.',
#  '7',
#  'Paxton Scott',
#  'WR',
#  '6-1',
#  '200',
#  'Sr.',
#  "St. Mark's School of Texas",
#  'Dallas, Texas',
#  '8',
#  'Nic Sani',
#  'TE',
#  '6-7',
#  '275',
#  'Sr.',
#  'Central Catholic',
#  'Turlock, Calif.',
#  '9',
#  'Sean Williams',
#  'DB',
#  '5-9',
#  '190',
#  'So.',
#  'Battle Ground Academy',
#  'Nolensville, Tenn.',
#  '10',
#  'Dylan Cadwallader',
#  'QB',
#  '6-2',
#  '190',
#  'Sr.',
#  'Prestonwood Christian',
#  'Frisco, Texas',
#  '10',
#  'Vachon Raye',
#  'CB',
#  '5-11',
#  '175',
#  'Sr.',
#  'Booker T. Washington',
#  'Atlanta, Ga.',
#  '11',
#  'Jace Henry',
#  'TE',
#  '6-4',
#  '270',
#  'Sr.',
#  'Lathrop',
#  'Fairbanks, Alaska',
#  '12',
#  'Jamal Cooper',
#  'DB',
#  '5-11',
#  '180',
#  'So.',
#  'Montgomery Academy',
#  'Montgomery, Ala.',
#  '12',
#  'Jackson Proctor',
#  'QB',
#  '6-1',
#  '205',
#  'Jr.',
#  'Kentwood',
#  'Kent, Wash.',
#  '13',
#  'Tyson Grimm',
#  'DB',
#  '6-1',
#  '215',
#  'So.',
#  'Archbishop Hoban',
#  'Akron, Ohio',
#  '13',
#  'Woods Ray',
#  'QB',
#  '6-2',
#  '210',
#  'Fy.',
#  'Homewood',
#  'Homewood, Ala.',
#  '14',
#  'Onye Onuoha',
#  'CB',
#  '5-11',
#  '195',
#  'Sr.',
#  'Green Valley Ranch',
#  'Denver, Colo.',
#  '15',
#  'D.J. Crowther',
#  'RB',
#  '5-11',
#  '205',
#  'So.',
#  'Christian Brothers',
#  'Sacramento, Calif.',
#  '16',
#  'Patrick Campbell',
#  'DB',
#  '5-11',
#  '190',
#  'So.',
#  'Brookwood',
#  'Snellville, Ga.',
#  '16',
#  'Grayson Saunier',
#  'QB',
#  '6-2',
#  '210',
#  'Fy.',
#  'Lafayette HS',
#  'Lafayette, La.',
#  '17',
#  'Nick Howard',
#  'QB',
#  '6-2',
#  '225',
#  '5th',
#  'Southwest',
#  'Green Bay, Wis.',
#  '18',
#  'Devon Lingle',
#  'QB',
#  '6-1',
#  '205',
#  'Sr.',
#  'Duncan U. Fletcher',
#  'Neptune Beach, Fla.',
#  '18',
#  'Matisse Weaver',
#  'PK',
#  '5-10',
#  '185',
#  'Fy.',
#  'Lander',
#  'Lander, Wyo.',
#  '19',
#  "Grayson O'Bara",
#  'WR',
#  '6-1',
#  '190',
#  'So.',
#  'Guyer',
#  'Argyle, Texas',
#  '20',
#  'Q Jones',
#  'RB',
#  '5-11',
#  '195',
#  'Jr.',
#  'Fountain-Fort Carson',
#  'Fountain, Colo.',
#  '21',
#  'Tyler Green',
#  'RB',
#  '5-10',
#  '210',
#  'Sr.',
#  'Mill Valley',
#  'Lenexa, Kan.',
#  '22',
#  'Alex Geraci',
#  'TE',
#  '6-3',
#  '235',
#  'Jr.',
#  'Don Bosco Prep',
#  'Cornwall-on-Hudson, N.Y.',
#  '23',
#  'Christian Benson',
#  'RB',
#  '5-6',
#  '190',
#  'Jr.',
#  'Parish Episcopal',
#  'DeSoto, Texas',
#  '24',
#  'Jordan Washington',
#  'DB',
#  '6-0',
#  '190',
#  'Jr.',
#  'JSerra',
#  'Escondido, Calif.',
#  '25',
#  'Tevita Moimoi',
#  'RB',
#  '6-0',
#  '225',
#  'Sr.',
#  'Sacred Heart Prep',
#  'Menlo Park, Calif.',
#  '26',
#  'Chris Corbo',
#  'TE',
#  '6-5',
#  '240',
#  'So.',
#  'West Essex',
#  'North Caldwell, N.J.',
#  '26',
#  'K.J. Edwards',
#  'DB',
#  '6-0',
#  '175',
#  'Fy.',
#  'East/Phillips Andover (Mass.)',
#  'Rochester, N.Y.',
#  '27',
#  'Desmin Jackson',
#  'RB',
#  '5-10',
#  '185',
#  'So.',
#  'Orange Lutheran',
#  'Menifee, Calif.',
#  '28',
#  'Chris Roper',
#  'RB',
#  '5-9',
#  '195',
#  'Fy.',
#  'Adairsville',
#  'Cartersville, Ga.',
#  '29',
#  'Zach Farris',
#  'DB',
#  '5-11',
#  '185',
#  'Jr.',
#  'Cardinal Gibbons',
#  'Coral Springs, Fla.',
#  '30',
#  'Jorden Barnes',
#  'CB',
#  '5-11',
#  '190',
#  'Fy.',
#  'Brentwood Academy',
#  'Nashville, Tenn.',
#  '30',
#  "Colin O'Garro",
#  'RB',
#  '6-0',
#  '205',
#  'Fy.',
#  'Iona Prep',
#  'New Rochelle, N.Y.',
#  '31',
#  'Sam Koscho',
#  'S',
#  '5-11',
#  '190',
#  '5th',
#  'Cardinal Mooney',
#  'Sarasota, Fla.',
#  '32',
#  'Josh Greene',
#  'LS',
#  '5-11',
#  '225',
#  '5th',
#  'The Benjamin School',
#  'Palm Beach Gardens, Fla.',
#  '32',
#  'Jonathan Nelson',
#  'WR',
#  '5-9',
#  '165',
#  'Fy.',
#  'Bridgeland',
#  'Cypress, Texas',
#  '33',
#  'Danny Cronin',
#  'LB',
#  '6-3',
#  '230',
#  'Sr.',
#  'IC Catholic Prep',
#  'Elmhurst, Ill.',
#  '34',
#  'Quinten Arello',
#  'S',
#  '6-1',
#  '210',
#  '5th',
#  'Staley',
#  'Kansas City, Mo.',
#  '35',
#  'Derrell Porter',
#  'DL',
#  '6-0',
#  '275',
#  'Jr.',
#  'Penn Hills/Worcester Academy',
#  'Penn Hills, Pa.',
#  '35',
#  'Owen Zalc',
#  'PK',
#  '5-10',
#  '160',
#  'Fy.',
#  'Green Hope',
#  'Cary, N.C.',
#  '36',
#  'Cameron Best-Alston',
#  'CB',
#  '6-2',
#  '195',
#  'Fy.',
#  'Conway',
#  'Conway, S.C.',
#  '37',
#  'Harrison Keith',
#  'S',
#  '6-0',
#  '200',
#  'Fy.',
#  'Choate',
#  'Fairfield, Conn.',
#  '38',
#  'Jack Noonan',
#  'DB',
#  '5-9',
#  '185',
#  'Sr.',
#  'Weston',
#  'Weston, Mass.',
#  '39',
#  'Carson Franks',
#  'S',
#  '6-0',
#  '205',
#  'Jr.',
#  'State College HS',
#  'State College, Pa.',
#  '40',
#  'Macklin Ayers',
#  'LB',
#  '6-3',
#  '235',
#  'Sr.',
#  'Upper Dauphin Area',
#  'Elizabethville, Pa.',
#  '41',
#  'Sean Harmon',
#  'TE',
#  '6-4',
#  '240',
#  'Jr.',
#  'Bishop Blanchet',
#  'Seattle, Wash.',
#  '42',
#  'Ross Parrish',
#  'TE',
#  '6-3',
#  '250',
#  'Sr.',
#  'Anderson',
#  'Cincinnati, Ohio',
#  '44',
#  'Marques White',
#  'LB',
#  '6-2',
#  '245',
#  '5th',
#  'Brophy Prep',
#  'Glendale, Ariz.',
#  '45',
#  'Joe Onuwabhagbe',
#  'DL',
#  '6-2',
#  '250',
#  'So.',
#  'Hebron',
#  'Carrollton, Texas',
#  '46',
#  'Yomi Babalola',
#  'LB',
#  '6-1',
#  '240',
#  'So.',
#  'James C. Enochs',
#  'Riverbank, Calif.',
#  '47',
#  'Taysire Williams',
#  'TE',
#  '6-4',
#  '225',
#  'Fy.',
#  'Jimtown',
#  'Elkhart, Ind.',
#  '48',
#  'Zyion Freer-Brown',
#  'LB',
#  '6-0',
#  '240',
#  'So.',
#  'St. Edward',
#  'Lorain, Ohio',
#  '49',
#  'Micah Green',
#  'LB',
#  '5-10',
#  '225',
#  'Jr.',
#  'North Central',
#  'Indianapolis, Ind.',
#  '50',
#  'Steve Simpkins',
#  'LB',
#  '6-2',
#  '220',
#  'Fy.',
#  'Summerville',
#  'Summerville, S.C.',
#  '51',
#  'Thaddeus Gianaris',
#  'LB',
#  '6-2',
#  '240',
#  'So.',
#  'Maine South',
#  'Park Ridge, Ill.',
#  '52',
#  'Braden Mullen',
#  'LB',
#  '6-3',
#  '240',
#  'Jr.',
#  'Loyola Academy',
#  'Glenview, Ill.',
#  '53',
#  'Nico Schwikal',
#  'LB',
#  '6-3',
#  '225',
#  'So.',
#  'Taft School (Conn.)',
#  'Schönfeld, Germany',
#  '54',
#  'Reese Spence',
#  'LB',
#  '5-11',
#  '200',
#  'Jr.',
#  "Eagle's Landing Christian Academy",
#  'Jonesboro, Ga.',
#  '55',
#  'Andy Belles',
#  'LS',
#  '6-3',
#  '210',
#  'Fy.',
#  'Houston HS',
#  'Germantown, Tenn.',
#  '56',
#  'Max Schlager',
#  'LB',
#  '6-1',
#  '185',
#  'Fy.',
#  'Trinity HS',
#  'Camp Hill, Pa.',
#  '56',
#  'Roland Waguespack',
#  'OL',
#  '6-4',
#  '275',
#  'Fy.',
#  'Jesuit',
#  'New Orleans, La.',
#  '57',
#  'Joshua Johnson',
#  'DE',
#  '6-2',
#  '245',
#  'Fy.',
#  'Statesboro/Phillips Exeter',
#  'Statesboro, Ga.',
#  '58',
#  'John Ballowe',
#  'LB',
#  '6-1',
#  '225',
#  'Jr.',
#  'Collegiate School',
#  'Richmond, Va.',
#  '59',
#  'Cameron Lee',
#  'LB',
#  '6-4',
#  '200',
#  'Fy.',
#  "Bishop O'Connell",
#  'Alexandria, Va.',
#  '59',
#  'Nick Marinaro',
#  'OL',
#  '6-1',
#  '285',
#  'Jr.',
#  "Benilde-St. Margaret's",
#  'Wayzata, Minn.',
#  '60',
#  'Nicholas Schwitzgebel',
#  'OL',
#  '6-1',
#  '300',
#  'Sr.',
#  'St. Ignatius',
#  'Cleveland, Ohio',
#  '61',
#  'Cayman Duncan',
#  'OL',
#  '6-6',
#  '280',
#  'Jr.',
#  'Kinkaid School',
#  'Spring, Texas',
#  '62',
#  'James Coslet',
#  'OL',
#  '6-2',
#  '270',
#  'Jr.',
#  'Watchung Hills',
#  'Millington, N.J',
#  '63',
#  'Kyle Brown',
#  'OL',
#  '6-4',
#  '280',
#  'Sr.',
#  'Marcellus',
#  'Marcellus, N.Y.',
#  '64',
#  'Tristan Holmbeck',
#  'OL',
#  '6-3',
#  '285',
#  'Jr.',
#  'Springside Chestnut Hill',
#  'Philadelphia, Pa.',
#  '65',
#  'Keoni Perkins',
#  'DE',
#  '6-3',
#  '235',
#  'Fy.',
#  'South Grand Prairie',
#  'Grand Prairie, Texas',
#  '66',
#  'Maxwell Wentz',
#  'OL',
#  '6-4',
#  '290',
#  'So.',
#  'Huntington',
#  'Huntington, W.Va.',
#  '67',
#  'Max Livingston',
#  'OL',
#  '6-3',
#  '275',
#  'Fy.',
#  'Grapevine',
#  'Colleyville, Texas',
#  '68',
#  'Francisco Caballero',
#  'OL',
#  '6-2',
#  '285',
#  'Fy.',
#  'Gulliver Prep',
#  'Miami, Fla.',
#  '69',
#  'Cam Davenport',
#  'OL',
#  '6-3',
#  '355',
#  'Fy.',
#  'Ben Davis',
#  'Indianapolis, Ind.',
#  '70',
#  'James Morrison',
#  'OL',
#  '6-6',
#  '255',
#  'Jr.',
#  "St. Joe's",
#  'Mahwah, N.J.',
#  '71',
#  'Will Prince',
#  'OL',
#  '6-5',
#  '250',
#  'Fy.',
#  'Avon Old Farms',
#  'West Hartford, Conn.',
#  '72',
#  'Vasean Washington',
#  'OL',
#  '6-5',
#  '285',
#  'So.',
#  'Springfield',
#  'Springfield, Ohio',
#  '73',
#  'Thomas Hartnett',
#  'OL',
#  '6-3',
#  '305',
#  'Sr.',
#  'Central Catholic',
#  'Pittsburgh, Pa.',
#  '74',
#  'Michael Betsy',
#  'OL',
#  '6-4',
#  '285',
#  'So.',
#  'Don Bosco Prep',
#  'Upper Saddle River, N.J.',
#  '75',
#  'Delby Lemieux',
#  'OL',
#  '6-4',
#  '280',
#  'So.',
#  'Duxbury',
#  'Duxbury, Mass.',
#  '77',
#  'Ethan Sipe',
#  'OL',
#  '6-5',
#  '295',
#  'Sr.',
#  'Ensworth School',
#  'Nashville, Tenn.',
#  '78',
#  'Godson Ajoku',
#  'OL',
#  '6-5',
#  '345',
#  'Fy.',
#  'Cantebury School (Conn.)',
#  'Lagos, Nigeria',
#  '79',
#  'Konstantin Spörk',
#  'OL',
#  '6-5',
#  '290',
#  'Jr.',
#  'Abteigymnasium Brauweiler/Fork Union (Va.)',
#  'Pulheim, Germany',
#  '80',
#  'Remington Gall',
#  'WR',
#  '6-5',
#  '225',
#  'Jr.',
#  'Avon',
#  'Avon, Ind.',
#  '81',
#  'Jarmone Sutherland',
#  'WR',
#  '5-11',
#  '195',
#  'Sr.',
#  'Isidore Newman School',
#  'New Orleans, La.',
#  '82',
#  'Jackson Gerard',
#  'WR',
#  '6-2',
#  '210',
#  'Jr.',
#  'St. Francis',
#  'West Chicago, Ill.',
#  '83',
#  'Daniel Haughton',
#  'WR',
#  '6-0',
#  '195',
#  'So.',
#  'Charlotte Latin',
#  'Matthews, N.C.',
#  '84',
#  'Painter Richards-Baker',
#  'WR',
#  '6-2',
#  '180',
#  'Jr.',
#  'Christ School',
#  'Hillsborough, N.C.',
#  '85',
#  'Jackson Namian',
#  'WR',
#  '6-1',
#  '195',
#  'Jr.',
#  'St. Albans School',
#  'Silver Spring, Md.',
#  '86',
#  'Nick Lemon',
#  'WR',
#  '5-10',
#  '180',
#  'Fy.',
#  'Cardinal Gibbons',
#  'Raleigh, N.C.',
#  '87',
#  'Ian Scott',
#  'WR',
#  '5-10',
#  '165',
#  'Fy.',
#  'Brentwood Academy',
#  'Brentwood, Tenn.',
#  '88',
#  'Ivan Hoyt',
#  'WR',
#  '6-1',
#  '195',
#  'So.',
#  'Cornerstone Christian',
#  'Boerne, Texas',
#  '89',
#  'Sean Ward',
#  'TE',
#  '6-5',
#  '240',
#  'So.',
#  'St. Ignatius',
#  'Cleveland, Ohio',
#  '90',
#  'Hank Knez',
#  'DL',
#  '6-4',
#  '290',
#  '5th',
#  'Glenbard West',
#  'Glen Ellyn, Ill.',
#  '91',
#  'Ejike Adele',
#  'DL',
#  '6-1',
#  '265',
#  'Jr.',
#  'Westminster School',
#  'Atlanta, Ga.',
#  '92',
#  'Dario Arazi',
#  'DE',
#  '6-6',
#  '275',
#  'Sr.',
#  'Brooklyn Tech',
#  'Brooklyn, N.Y.',
#  '93',
#  'Jabari Johnson',
#  'DE',
#  '6-3',
#  '255',
#  'So.',
#  'University Laboratory School',
#  'Zachary, La.',
#  '94',
#  'Charles Looes',
#  'DL',
#  '6-3',
#  '275',
#  '5th',
#  'Pascack Valley',
#  'Hillsdale, N.J.',
#  '95',
#  'Bruce Williams',
#  'DE',
#  '6-2',
#  '255',
#  'Fy.',
#  'Huron',
#  'Ann Arbor, Mich.',
#  '96',
#  'Isaiah Golonka',
#  'DL',
#  '6-2',
#  '260',
#  'Jr.',
#  'Canterbury School',
#  'Huntsville, Ala.',
#  '97',
#  'Jaylin Rainey',
#  'DL',
#  '6-2',
#  '275',
#  '5th',
#  'White Station',
#  'Memphis, Tenn.',
#  '98',
#  'Gannon McCorkle',
#  'DE',
#  '6-3',
#  '270',
#  'Sr.',
#  'Arundel/Phillips Exeter',
#  'Odenton, Md.',
#  '99',
#  'Dakota Quiñonez',
#  'DL',
#  '6-1',
#  '260',
#  'So.',
#  'James F. Byrnes',
#  'Moore, S.C.']

# %%
#creating dataframe

#create dictionary first
data = {}
data["jersey"] = [info[num] for num in range(0,len(info),8)]
data["names"] = [info[num] for num in range(1,len(info),8)]
data["position"] = [info[num] for num in range(2,len(info),8)]
data["height"] = [info[num] for num in range(3,len(info),8)]
data["weight"] = [info[num] for num in range(4,len(info),8)]
data["year"] = [info[num] for num in range(5,len(info),8)]
data["highschool"] = [info[num] for num in range(6,len(info),8)]
data["hometown"] = [info[num] for num in range(6,len(info),8)]



df = pd.DataFrame(data)
df.set_index("jersey")
# Out:
#                       names position height weight year  \
# jersey
# 0              Josiah Green       DL    6-0    265  Jr.
# 1              Davis Golick        P    6-1    210  Jr.
# 2                Cam Maddox        S    6-2    205  Sr.
# 3              Isaac Boston       WR   5-10    180  Sr.
# 4       Leonard St. Gourdin        S    6-3    205  Sr.
# ...                     ...      ...    ...    ...  ...
# 95           Bruce Williams       DE    6-2    255  Fy.
# 96           Isaiah Golonka       DL    6-2    260  Jr.
# 97            Jaylin Rainey       DL    6-2    275  5th
# 98          Gannon McCorkle       DE    6-3    270  Sr.
# 99          Dakota Quiñonez       DL    876    260  So.
#
#                                  highschool  \
# jersey
# 0                             North Central
# 1                          Woodward Academy
# 2       Sun Valley/Cheshire Academy (Conn.)
# 3                       Springfield Central
# 4         Malden Catholic/Deerfield Academy
# ...                                     ...
# 95                                    Huron
# 96                        Canterbury School
# 97                            White Station
# 98                  Arundel/Phillips Exeter
# 99                          James F. Byrnes
#
#                                    hometown
# jersey
# 0                             North Central
# 1                          Woodward Academy
# 2       Sun Valley/Cheshire Academy (Conn.)
# 3                       Springfield Central
# 4         Malden Catholic/Deerfield Academy
# ...                                     ...
# 95                                    Huron
# 96                        Canterbury School
# 97                            White Station
# 98                  Arundel/Phillips Exeter
# 99                          James F. Byrnes
#
# [110 rows x 7 columns]

# %%
b.quit()

# %%
#Data Analysis

# What are the Geographic, socio-economic, social and demographic characteristics of their communities?

# What are the characteristics of their highschools (school size, urban/rural/suburban classification, 
# student demographics, title 1 status)?

# What other interesting trends can you find?
