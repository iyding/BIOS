# %%
import pandas as pd

cor_df = pd.read_csv("Cornell_sports_cleaned.csv")

col_dart_df = pd.read_csv("Dartmouth_Columbia_Cleaned.csv")

harv_pen_df = pd.read_csv("jack_final_df.csv")

census_df = pd.read_csv("CENSUS-DATA.csv")

prin_df = pd.read_csv("Princeton_Athletics_Clean.csv")

# %%
yale_df = pd.read_csv("Yale_finished.csv")
brown_df = pd.read_csv("brown.csv")

# %%
def stand_city_name(city):
    us_state_abbrev = {
    'ALA.': 'Alabama',
    'AK.': 'Alaska',
    'ARIZ.': 'Arizona',
    'AR.': 'Arkansas',
    'CALIF.': 'California',
    'CA': 'California',
    'COLO.': 'Colorado',
    'CO': 'Colorado',
    'CONN.': 'Connecticut',
    'CT': 'Connecticut',
    'D.C.': 'District of Columbia',
    'DE.': 'Delaware',
    'FLA.': 'Florida',
    'FL': 'Florida',
    'GA.': 'Georgia',
    'HI.': 'Hawaii',
    'ID.': 'Idaho',
    'ILL.': 'Illinois',
    'IND.': 'Indiana',
    'IA.': 'Iowa',
    'KAN.': 'Kansas',
    'KY.': 'Kentucky',
    'LA.': 'Louisiana',
    'ME.': 'Maine',
    'MD.': 'Maryland',
    'MASS.': 'Massachusetts',
    'MA': 'Massachusetts',
    'MICH.': 'Michigan',
    'MINN.': 'Minnesota',
    'MS.': 'Mississippi',
    'MO.': 'Missouri',
    'MT.': 'Montana',
    'NE.': 'Nebraska',
    'NEV.': 'Nevada',
    'N.H.': 'New Hampshire',
    'N.J.': 'New Jersey',
    'NJ': 'New Jersey',
    'N.M.': 'New Mexico',
    'N.Y.': 'New York',
    'NY': 'New York',
    'N.C.': 'North Carolina',
    'N.D.': 'North Dakota',
    'OH.': 'Ohio',
    'OH': 'Ohio',
    'OKLA.': 'Oklahoma',
    'ORE.': 'Oregon',
    'PA.': 'Pennsylvania',
    'R.I.': 'Rhode Island',
    'S.C.': 'South Carolina',
    'S.D.': 'South Dakota',
    'TENN.': 'Tennessee',
    'TX.': 'Texas',
    'UT.': 'Utah',
    'VT.': 'Vermont',
    'VA.': 'Virginia',
    'WASH.': 'Washington',
    'W.V.': 'West Virginia',
    'WIS.': 'Wisconsin',
    'WY.': 'Wyoming',
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
    }
    if city is None or not isinstance(city, str) or ',' not in city:
        return None

    city_parts  = city.split(", ")
    city_name = city_parts[0].strip().lower()
    
    if len(city_parts) < 2:
        return city_name
    
    state_abbr = city_parts[1].strip().lower()
    state_name = us_state_abbrev.get(state_abbr.upper(), state_abbr)
    
    return f"{city_name}, {state_name.lower()}"

# %%
i = 0
df_list = ['yale_df', 'brown_df', 'harv_pen_df', 'cor_df']
for df in [yale_df, brown_df, harv_pen_df, cor_df]:
    

    df['std_city_name'] = df['Hometown'].apply(stand_city_name)

    df[['city', 'state']] = df['std_city_name'].str.split(',', 1, expand=True)
    df['state'] = df['state'].str.lstrip()
    df.to_csv(f"{df_list[i]}_real_final.csv")
    i += 1
# Out:
# C:\Users\8benb\AppData\Local\Temp\ipykernel_30808\1185865101.py:8: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['city', 'state']] = df['std_city_name'].str.split(',', 1, expand=True)

# %%
prin_df["College"] = 'Princeton'

# %%
brown_df.to_csv("brown_is_finished.csv")

# %%
prin_df.to_csv("prin_df_real_final.csv")

# %%
yale_df["College"] = 'Yale'

yale_df.to_csv("Yale_is_finished.csv")
